# %%
from scipy.stats import wilcoxon
import pandas as pd
import shutil

# %%
metric_name = ['acs','gm','f1']
def teste_estatistico(result_df):
    for i in range(0,3):
        columns = result_df.columns

        data1 = result_df[columns[i]]
        data2 = result_df[columns[i+3]]

        stat, p = wilcoxon(data1, data2)
        print('stat=%.3f, p=%.3f' % (stat, p))
        if p > 0.05:
          print('H0 not rejected for {} metric: Probably the same distribution'.format(metric_name[i]))
        else:
          print('H0 rejected for {} metric: Probably different distributions'.format(metric_name[i]))

# %% [markdown]
# ## MNIST

# %%
result_df = pd.read_csv('data_projeto/data_MNIST.csv', header=[0])
result_df

# %%
teste_estatistico(result_df)

# %% [markdown]
# ## FASHIONMNIST

# %%
result_df = pd.read_csv('data_projeto/data_FMNIST.csv', header=[0])

# %%
result_df
# Out:
#     acs_array_smote_total  gm_array_smote_total  f1macro_array_smote_total  \
# 0                0.959987              0.884368                   0.791665
# 1                0.960223              0.885085                   0.791408
# 2                0.959590              0.883170                   0.791802
# 3                0.958063              0.878545                   0.782429
# 4                0.960620              0.886275                   0.791167
# 5                0.956120              0.872596                   0.771396
# 6                0.956847              0.874804                   0.775281
# 7                0.960770              0.886726                   0.795618
# 8                0.959997              0.884392                   0.791225
# 9                0.961250              0.888176                   0.799533
# 10               0.960913              0.887150                   0.796665
# 11               0.960020              0.884478                   0.792035
# 12               0.960520              0.885955                   0.794241
# 13               0.959467              0.882729                   0.788142
# 14               0.960003              0.884436                   0.787825
# 15               0.959347              0.882431                   0.784618
# 16               0.960197              0.884999                   0.794319
# 17               0.958320              0.879297                   0.781752
# 18               0.960197              0.884999                   0.794319
# 19               0.958050              0.878507                   0.786274
# 20               0.961640              0.889356                   0.799812
# 21               0.958133              0.878700                   0.785094
# 22               0.961997              0.890419                   0.800994
# 23               0.956497              0.873801                   0.773430
# 24               0.960643              0.886338                   0.796917
# 25               0.960213              0.885057                   0.791476
# 26               0.959863              0.884020                   0.792181
# 27               0.961977              0.890366                   0.803272
# 28               0.958477              0.879757                   0.783673
# 29               0.957743              0.877536                   0.780524
# 30               0.959303              0.882292                   0.789548
# 31               0.960747              0.886672                   0.796111
# 32               0.961670              0.889447                   0.801075
# 33               0.958840              0.880895                   0.786334
# 34               0.961607              0.889247                   0.800017
# 35               0.958787              0.880762                   0.784153
# 36               0.961670              0.889447                   0.801075
# 37               0.958840              0.880895                   0.786334
# 38               0.955920              0.872050                   0.773478
# 39               0.957700              0.877401                   0.776913
# 40               0.959740              0.883574                   0.790614
# 41               0.959473              0.882793                   0.786543
# 42               0.956983              0.875217                   0.775351
# 43               0.960300              0.885305                   0.792359
# 44               0.958493              0.879868                   0.782210
# 45               0.961000              0.887427                   0.797317
# 46               0.960340              0.885443                   0.796335
# 47               0.962957              0.893316                   0.805088
# 48               0.958707              0.880491                   0.783088
# 49               0.960340              0.885443                   0.796335
# 50               0.960340              0.885443                   0.796335
# 51               0.962957              0.893316                   0.805088
# 52               0.960883              0.887057                   0.795876
#
#     acs_array_adasyn_total  gm_array_adasyn_total  \
# 0                 0.956137               0.872597
# 1                 0.957657               0.877264
# 2                 0.959243               0.882117
# 3                 0.963203               0.894049
# 4                 0.960120               0.884771
# 5                 0.956943               0.875109
# 6                 0.958347               0.879331
# 7                 0.955770               0.871423
# 8                 0.958677               0.880375
# 9                 0.959960               0.884298
# 10                0.959450               0.882728
# 11                0.957083               0.875578
# 12                0.959550               0.883040
# 13                0.960190               0.884955
# 14                0.959623               0.883279
# 15                0.960147               0.884799
# 16                0.958530               0.879974
# 17                0.959370               0.882518
# 18                0.958530               0.879974
# 19                0.960487               0.885877
# 20                0.958607               0.880151
# 21                0.960673               0.886437
# 22                0.960273               0.885202
# 23                0.960817               0.886883
# 24                0.959033               0.881485
# 25                0.957390               0.876514
# 26                0.960130               0.884819
# 27                0.960193               0.884960
# 28                0.959937               0.884208
# 29                0.957643               0.877276
# 30                0.958540               0.879939
# 31                0.958340               0.879338
# 32                0.958137               0.878760
# 33                0.960903               0.887124
# 34                0.960147               0.884866
# 35                0.960427               0.885604
# 36                0.958137               0.878760
# 37                0.960903               0.887124
# 38                0.956497               0.873745
# 39                0.956033               0.872327
# 40                0.959000               0.881364
# 41                0.961363               0.888526
# 42                0.962263               0.891233
# 43                0.959307               0.882322
# 44                0.957887               0.878013
# 45                0.956123               0.872650
# 46                0.960287               0.885290
# 47                0.958260               0.879069
# 48                0.958467               0.879770
# 49                0.960287               0.885290
# 50                0.960287               0.885290
# 51                0.958260               0.879069
# 52                0.959290               0.882236
#
#     f1macro_array_adasyn_total;;;;;;;
# 0                            0.771474
# 1                            0.777952
# 2                            0.784199
# 3                            0.810287
# 4                            0.792928
# 5                            0.776819
# 6                            0.782652
# 7                            0.763648
# 8                            0.783520
# 9                            0.787765
# 10                           0.787100
# 11                           0.775849
# 12                           0.787024
# 13                           0.788752
# 14                           0.785808
# 15                           0.795069
# 16                           0.787077
# 17                           0.785213
# 18                           0.787077
# 19                           0.790193
# 20                           0.782650
# 21                           0.792769
# 22                           0.791547
# 23                           0.792962
# 24                           0.788154
# 25                           0.779811
# 26                           0.791187
# 27                           0.792155
# 28                           0.784802
# 29                           0.775973
# 30                           0.783048
# 31                           0.777962
# 32                           0.780712
# 33                           0.794585
# 34                           0.794586
# 35                           0.792622
# 36                           0.780712
# 37                           0.794585
# 38                           0.771925
# 39                           0.768590
# 40                           0.783980
# 41                           0.797594
# 42                           0.803111
# 43                           0.785388
# 44                           0.777976
# 45                           0.770607
# 46                           0.790400
# 47                           0.782319
# 48                           0.777180
# 49                           0.790400
# 50                           0.790400
# 51                           0.782319
# 52                           0.784634

# %%
teste_estatistico(result_df)
# Out:
# stat=488.000, p=0.044
# H0 rejected for acs metric: Probably different distributions
# stat=489.000, p=0.045
# H0 rejected for gm metric: Probably different distributions
# stat=384.000, p=0.003
# H0 rejected for f1 metric: Probably different distributions

# %% [markdown]
# ## CIFAR-10

# %%
result_df = pd.read_csv('data_projeto/data_CIFAR10.csv', header=[0])
result_df
# Out:
#     acs_array_smote_total  gm_array_smote_total  f1macro_array_smote_total  \
# 0                0.881103              0.615221                   0.372066
# 1                0.880340              0.612301                   0.367378
# 2                0.878217              0.603789                   0.352476
# 3                0.880347              0.612279                   0.370521
# 4                0.878873              0.606300                   0.359763
# 5                0.879633              0.609450                   0.366008
# 6                0.880547              0.612936                   0.378041
# 7                0.882737              0.621838                   0.385219
# 8                0.880097              0.611326                   0.367711
# 9                0.880917              0.614406                   0.375215
# 10               0.883717              0.625673                   0.387862
# 11               0.878897              0.605934                   0.361770
#
#     acs_array_adasyn_total  gm_array_adasyn_total  f1macro_array_adasyn_total
# 0                 0.880893               0.614391                    0.368918
# 1                 0.883080               0.622835                    0.379110
# 2                 0.880440               0.612457                    0.365554
# 3                 0.882057               0.619108                    0.371781
# 4                 0.878480               0.604884                    0.347360
# 5                 0.882293               0.619968                    0.374847
# 6                 0.882283               0.620034                    0.379531
# 7                 0.881950               0.618346                    0.374958
# 8                 0.883483               0.624747                    0.381552
# 9                 0.883117               0.623172                    0.383924
# 10                0.882723               0.621465                    0.379272
# 11                0.880153               0.611284                    0.367608

# %%
teste_estatistico(result_df)
# Out:
# stat=10.000, p=0.021
# H0 rejected for acs metric: Probably different distributions
# stat=10.000, p=0.021
# H0 rejected for gm metric: Probably different distributions
# stat=26.000, p=0.339
# H0 not rejected for f1 metric: Probably the same distribution

# %% [markdown]
# ## SVHN

# %%
result_df = pd.read_csv('data_projeto/data_SVHN.csv', header=[0])
result_df

# %%
teste_estatistico(result_df)
